# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl
import pandas as pd
from collections import OrderedDict
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# %%
# Get stats for MS Dhoni

# %%
url="http://stats.espncricinfo.com/ci/engine/player/34102.html?class=1;template=results;type=batting;view=match"
html = urllib.request.urlopen(url, context=ctx).read()
player_name = ''

# %%
def get_table_headers():
    global player_name
    bs=BeautifulSoup(html, "lxml")
    mydivs = bs.findAll("div", {"class": "icc-home"})
    player_name = mydivs[0].findAll("a")[0].text.split("/")[2]
    temp_data=OrderedDict()
    list_of_dict=[]
    bs=BeautifulSoup(html, "lxml")
    headers_soup=bs.find_all("tr",{"class":"headlinks"})
    headers_tag = headers_soup[0].find_all("th")
    list_of_headers = []
    for header in headers_tag:
        list_of_headers.append(header.text)
    return list_of_headers

# %%
def get_stats_list():
    temp_data=OrderedDict()
    list_of_dict=[]
    bs=BeautifulSoup(html, "lxml")
    table_body=bs.find_all('tbody')
    stats_table = table_body[1]
    rows = stats_table.find_all("tr")
    table_data_list = []
    for row in rows:
        row_data = []
        col = row.find_all("td")
        row_data = [c.text.strip() for c in col]
        table_data_list.append(row_data)
    return table_data_list

# %%
list_of_headers = get_table_headers()
list_of_headers[-1] = 'Match No'

table_data_list = get_stats_list()

# %%
data_frame = pd.DataFrame(table_data_list)
data_frame.columns = list_of_headers

# %%
def formatRuns(runs):
    runs = runs.replace("*",'')
    try:
        return int(runs)
    except:
        return 0

# %%
def formatDate(date):
    year = date.split(" ")[-1]
    return year

# %%
def clean_data_frame(data_frame):
    data_frame['Bat1'] = data_frame['Bat1'].apply(lambda runs: formatRuns(runs))
    data_frame['Bat2'] = data_frame['Bat2'].apply(lambda runs: formatRuns(runs))
    data_frame['Runs'] = data_frame['Runs'].apply(lambda runs: formatRuns(runs))
    data_frame['Year'] = data_frame['Start Date'].apply(lambda date: formatDate(date))
    return data_frame

# %%
data_frame = clean_data_frame(data_frame)

# %%
res = data_frame.groupby(['Year']).agg({'Bat1': 'sum','Bat2':'sum', 'Opposition':'count'})
res=res.rename(columns = {'Opposition':'Matches'})
dictio = res.to_dict('index')
res.reset_index(level=0, inplace=True)
res
res.rename(columns={'Bat1':'1st Innings','Bat2':"2nd Innings"}, inplace=True)

# %%
# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')
# from matplotlib.figure import Figure


plt.figure(figsize=(20,20))
plt.figure().suptitle('test title', fontsize=20)
res.plot(kind='bar',x="Year",y=['1st Innings','2nd Innings'],color=['Blue','Green'], title=player_name)
# res.plot(kind='bar',x="Year",y='Bat2',color='Red',ax=ax, title=player_name)
plt.savefig("file.jpg",dpi=200)
plt.show
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if __name__ == '__main__':
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
data_frame
# Out:
#     Bat1  Bat2  Runs   BF     SR  4s  6s        Opposition         Ground  \
# 0    177     0   177  301  58.80  23   1     v West Indies        Kolkata
# 1    111     0   111  127  87.40  11   3     v West Indies         Mumbai
# 2     14     6    20   55  36.36   2   0    v South Africa   Johannesburg
# 3      0    25    25   47  53.19   2   1    v South Africa         Durban
# 4     72    19    91  179  50.83  10   1     v New Zealand       Auckland
