# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl
import pandas as pd
from collections import OrderedDict
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# %%
# Get stats for MS Dhoni

# %%
url='http://stats.espncricinfo.com/ci/engine/player/34102.html?class=3;template=results;type=batting;view=innings'
html = urllib.request.urlopen(url, context=ctx).read()
player_name = ''

# %%
def get_table_headers():
    global player_name
    bs=BeautifulSoup(html, "lxml")
    mydivs = bs.findAll("div", {"class": "icc-home"})
    player_name = mydivs[0].findAll("a")[0].text.split("/")[2]
    temp_data=OrderedDict()
    list_of_dict=[]
    bs=BeautifulSoup(html, "lxml")
    headers_soup=bs.find_all("tr",{"class":"headlinks"})
    headers_tag = headers_soup[0].find_all("th")
    list_of_headers = []
    for header in headers_tag:
        list_of_headers.append(header.text)
    return list_of_headers

# %%
def get_stats_list():
    temp_data=OrderedDict()
    list_of_dict=[]
    bs=BeautifulSoup(html, "lxml")
    table_body=bs.find_all('tbody')
    stats_table = table_body[1]
    rows = stats_table.find_all("tr")
    table_data_list = []
    for row in rows:
        row_data = []
        col = row.find_all("td")
        row_data = [c.text.strip() for c in col]
        table_data_list.append(row_data)
    return table_data_list

# %%
list_of_headers = get_table_headers()
list_of_headers[-1] = 'Match No'
table_data_list = get_stats_list()

# %%
data_frame = pd.DataFrame(table_data_list)
data_frame.columns = list_of_headers

# %%
data_frame
# Out:
#     Runs Mins  BF  4s  6s      SR Pos Dismissal Inns         Opposition  \
# 0    DNB    -   -   -   -       -   -         -    1          v England
# 1    50*   52  40   7   2  125.00   5   not out    1     v South Africa
# 2     8*   11   5   0   1  160.00   6   not out    1        v Australia
# 3    30*   22  16   2   1  187.50   6   not out    1         v Pakistan
# 4    DNB    -   -   -   -       -   -         -    2        v Australia
# 5      8   15   8   1   0  100.00   5    bowled    1        v Australia
# 6      4   13  11   0   0   36.36   6    caught    2        v Sri Lanka
# 7      7    9   7   0   1  100.00   4    caught    1      v New Zealand
# 8     36   34  23   3   2  156.52   2    bowled    1       v Bangladesh
# 9    52*   61  45   4   1  115.55   2   not out    2          v Ireland
# 10     5    6   3   1   0  166.66   2    caught    1      v West Indies
# 11     9    7   8   1   0  112.50   2    bowled    2          v England
# 12    29   39  28   3   0  103.57   2    caught    2     v South Africa
# 13     3    -   4   0   0   75.00   5   run out    2        v Sri Lanka
# 14   79*   65  46   4   6  171.73   4   not out    2        v Australia
# 15     5   10   8   1   0   62.50   4    caught    2      v West Indies
# 16   DNB    -   -   -   -       -   -         -    1        v Sri Lanka
# 17    10   22  15   1   0   66.66   4   stumped    2         v Zimbabwe
# 18    0*    1   0   0   0       -   5   not out    2         v Zimbabwe
# 19    53   38  34   5   2  155.88   3    caught    1     v South Africa
# 20    26   33  23   0   2  113.04   6    bowled    1      v West Indies
# 21     1    7   3   0   0   33.33   5   stumped    1          v England
# 22     0    2   1   0   0    0.00   5    bowled    2        v Australia
# 23   DNB    -   -   -   -       -   -         -    2        v Australia
# 24   DNB    -   -   -   -       -   -         -    2     v South Africa
# 25   DNB    -   -   -   -       -   -         -    1        v Sri Lanka
# 26    4*    2   2   0   0  200.00   6   not out    2      v New Zealand
# 27    1*    2   1   0   0  100.00   7   not out    1      v Afghanistan
# 28   55*   48  33   5   1  166.66   4   not out    1          v England
# 29     1    5   2   0   0   50.00   5    bowled    1        v Australia
# ..   ...  ...  ..  ..  ..     ...  ..       ...  ... ..             ...
# 68    17   21  13   2   0  130.76   1    caught    1        v Sri Lanka
# 69   118   61  43  12  10  274.41   1    caught    1        v Sri Lanka
# 70    27   31  20   4   1  135.00   1    caught    2        v Sri Lanka
# 71    21    8   9   2   2  233.33   1    caught    1     v South Africa
# 72     0    5   1   0   0    0.00   2       lbw    1     v South Africa
# 73    11    9   8   2   0  137.50   1       lbw    1     v South Africa
# 74     0    -   4   0   0    0.00   1    caught    1        v Sri Lanka
# 75    17    -  13   3   0  130.76   1    bowled    2       v Bangladesh
# 76    11    -   7   1   1  157.14   1    caught    2        v Sri Lanka
# 77    89    -  61   5   5  145.90   1   run out    1       v Bangladesh
# 78    56    -  42   4   3  133.33   2    caught    2       v Bangladesh
# 79    97   87  61   8   5  159.01   1    bowled    1          v Ireland
# 80     0    -   2   0   0    0.00   4    caught    1          v Ireland
# 81    32    -  30   3   1  106.66   2    caught    2          v England
# 82     5    -   9   1   0   55.55   1    caught    1          v England
# 83  100*    -  56  11   5  178.57   1   not out    2          v England
# 84     6    -   6   1   0  100.00   1    caught    2      v West Indies
# 85  111*   95  61   8   7  181.96   1   not out    1      v West Indies
# 86     4    -   6   1   0   66.66   2    caught    2      v West Indies
# 87     7    -   8   0   0   87.50   1    caught    2        v Australia
# 88  TDNB    -   -   -   -       -   -         -    -        v Australia
# 89    23    -  16   1   2  143.75   1    bowled    2        v Australia
# 90     1   10   5   0   0   20.00   1    caught    2      v New Zealand
# 91    50   40  29   3   4  172.41   1    caught    2      v New Zealand
# 92    38   63  32   3   0  118.75   2    caught    2      v New Zealand
# 93     5   11   8   0   0   62.50   1    caught    1        v Australia
# 94    24    -  25   2   2   96.00   1    caught    2      v West Indies
# 95    67    -  51   6   3  131.37   1    caught    1      v West Indies
# 96    12   21  12   0   2  100.00   1       lbw    2     v South Africa
# 97     9   11   8   2   0  112.50   2    caught    1     v South Africa
#
#                Ground   Start Date    Match No
# 0              Durban  19 Sep 2007   T20I # 40
# 1              Durban  20 Sep 2007   T20I # 43
# 2              Durban  22 Sep 2007   T20I # 45
# 3        Johannesburg  24 Sep 2007   T20I # 46
# 4         Mumbai (BS)  20 Oct 2007   T20I # 47
# 5           Melbourne   1 Feb 2008   T20I # 52
# 6       Colombo (RPS)  10 Feb 2009   T20I # 82
# 7        Christchurch  25 Feb 2009   T20I # 84
# 8          Nottingham   6 Jun 2009   T20I # 93
# 9          Nottingham  10 Jun 2009  T20I # 101
# 10             Lord's  12 Jun 2009  T20I # 105
# 11             Lord's  14 Jun 2009  T20I # 109
# 12         Nottingham  16 Jun 2009  T20I # 113
# 13             Nagpur   9 Dec 2009  T20I # 126
# 14         Bridgetown   7 May 2010  T20I # 165
# 15         Bridgetown   9 May 2010  T20I # 169
# 16         Gros Islet  11 May 2010  T20I # 173
# 17             Harare  12 Jun 2010  T20I # 182
# 18             Harare  13 Jun 2010  T20I # 183
# 19             Durban   9 Jan 2011  T20I # 196
# 20      Port of Spain   4 Jun 2011  T20I # 200
# 21         Manchester  31 Aug 2011  T20I # 204
# 22             Sydney   1 Feb 2012  T20I # 217
# 23          Melbourne   3 Feb 2012  T20I # 218
# 24       Johannesburg  30 Mar 2012  T20I # 242
# 25          Pallekele   7 Aug 2012  T20I # 255
# 26            Chennai  11 Sep 2012  T20I # 261
# 27      Colombo (RPS)  19 Sep 2012  T20I # 265
# 28      Colombo (RPS)  23 Sep 2012  T20I # 272
# 29      Colombo (RPS)  28 Sep 2012  T20I # 278
# ..                ...          ...         ...
# 68            Cuttack  20 Dec 2017  T20I # 633
# 69             Indore  22 Dec 2017  T20I # 634
# 70             Mumbai  24 Dec 2017  T20I # 635
# 71       Johannesburg  18 Feb 2018  T20I # 652
# 72          Centurion  21 Feb 2018  T20I # 654
# 73          Cape Town  24 Feb 2018  T20I # 655
# 74      Colombo (RPS)   6 Mar 2018  T20I # 656
# 75      Colombo (RPS)   8 Mar 2018  T20I # 657
# 76      Colombo (RPS)  12 Mar 2018  T20I # 659
# 77      Colombo (RPS)  14 Mar 2018  T20I # 660
# 78      Colombo (RPS)  18 Mar 2018  T20I # 662
# 79  Dublin (Malahide)  27 Jun 2018  T20I # 678
# 80  Dublin (Malahide)  29 Jun 2018  T20I # 680
# 81         Manchester   3 Jul 2018  T20I # 684
# 82            Cardiff   6 Jul 2018  T20I # 688
# 83            Bristol   8 Jul 2018  T20I # 690
# 84            Kolkata   4 Nov 2018  T20I # 707
# 85            Lucknow   6 Nov 2018  T20I # 709
# 86            Chennai  11 Nov 2018  T20I # 710
# 87           Brisbane  21 Nov 2018  T20I # 712
# 88          Melbourne  23 Nov 2018  T20I # 713
# 89             Sydney  25 Nov 2018  T20I # 714
# 90         Wellington   6 Feb 2019  T20I # 735
# 91           Auckland   8 Feb 2019  T20I # 737
# 92           Hamilton  10 Feb 2019  T20I # 738
# 93      Visakhapatnam  24 Feb 2019  T20I # 748
# 94         Lauderhill   3 Aug 2019  T20I # 842
# 95         Lauderhill   4 Aug 2019  T20I # 843
# 96             Mohali  18 Sep 2019  T20I # 888
# 97          Bengaluru  22 Sep 2019  T20I # 893
#
# [98 rows x 14 columns]

# %%
def formatRuns(runs):
    runs = runs.replace("*",'')
    try:
        return int(runs)
    except:
        return 0

# %%
def formatDate(date):
    year = date.split(" ")[-1]
    return year

# %%
def clean_data_frame(data_frame):
    data_frame['Runs'] = data_frame['Runs'].apply(lambda runs: formatRuns(runs))
    data_frame['Year'] = data_frame['Start Date'].apply(lambda date: formatDate(date))
    data_frame = data_frame.drop('', 1)
    return data_frame

# %%
data_frame = clean_data_frame(data_frame)
data_frame.set_index("Match No",inplace=True)
data_dict = data_frame.to_dict('index')
data_dict
# Out:
# {'T20I # 40': {'Runs': 0,
#   'Mins': '-',
#   'BF': '-',
#   '4s': '-',
#   '6s': '-',
#   'SR': '-',
#   'Pos': '-',
#   'Dismissal': '-',
#   'Inns': '1',
#   'Opposition': 'v England',
#   'Ground': 'Durban',
#   'Start Date': '19 Sep 2007',
#   'Year': '2007'},
#  'T20I # 43': {'Runs': 50,
#   'Mins': '52',
#   'BF': '40',
#   '4s': '7',
#   '6s': '2',
#   'SR': '125.00',
#   'Pos': '5',
#   'Dismissal': 'not out',
#   'Inns': '1',
#   'Opposition': 'v South Africa',
#   'Ground': 'Durban',
#   'Start Date': '20 Sep 2007',
#   'Year': '2007'},
#  'T20I # 45': {'Runs': 8,
#   'Mins': '11',
#   'BF': '5',
#   '4s': '0',
#   '6s': '1',
#   'SR': '160.00',
#   'Pos': '6',
#   'Dismissal': 'not out',
#   'Inns': '1',
#   'Opposition': 'v Australia',
#   'Ground': 'Durban',
#   'Start Date': '22 Sep 2007',
#   'Year': '2007'},
#  'T20I # 46': {'Runs': 30,
#   'Mins': '22',
#   'BF': '16',
#   '4s': '2',
#   '6s': '1',
#   'SR': '187.50',
#   'Pos': '6',
#   'Dismissal': 'not out',
#   'Inns': '1',
#   'Opposition': 'v Pakistan',
#   'Ground': 'Johannesburg',
#   'Start Date': '24 Sep 2007',
#   'Year': '2007'},
#  'T20I # 47': {'Runs': 0,
#   'Mins': '-',
#   'BF': '-',
#   '4s': '-',
#   '6s': '-',
#   'SR': '-',
#   'Pos': '-',
#   'Dismissal': '-',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Mumbai (BS)',
#   'Start Date': '20 Oct 2007',
#   'Year': '2007'},
#  'T20I # 52': {'Runs': 8,
#   'Mins': '15',
#   'BF': '8',
#   '4s': '1',
#   '6s': '0',
#   'SR': '100.00',
#   'Pos': '5',
#   'Dismissal': 'bowled',
#   'Inns': '1',
#   'Opposition': 'v Australia',
#   'Ground': 'Melbourne',
#   'Start Date': '1 Feb 2008',
#   'Year': '2008'},
#  'T20I # 82': {'Runs': 4,
#   'Mins': '13',
#   'BF': '11',
#   '4s': '0',
#   '6s': '0',
#   'SR': '36.36',
#   'Pos': '6',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '10 Feb 2009',
#   'Year': '2009'},
#  'T20I # 84': {'Runs': 7,
#   'Mins': '9',
#   'BF': '7',
#   '4s': '0',
#   '6s': '1',
#   'SR': '100.00',
#   'Pos': '4',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v New Zealand',
#   'Ground': 'Christchurch',
#   'Start Date': '25 Feb 2009',
#   'Year': '2009'},
#  'T20I # 93': {'Runs': 36,
#   'Mins': '34',
#   'BF': '23',
#   '4s': '3',
#   '6s': '2',
#   'SR': '156.52',
#   'Pos': '2',
#   'Dismissal': 'bowled',
#   'Inns': '1',
#   'Opposition': 'v Bangladesh',
#   'Ground': 'Nottingham',
#   'Start Date': '6 Jun 2009',
#   'Year': '2009'},
#  'T20I # 101': {'Runs': 52,
#   'Mins': '61',
#   'BF': '45',
#   '4s': '4',
#   '6s': '1',
#   'SR': '115.55',
#   'Pos': '2',
#   'Dismissal': 'not out',
#   'Inns': '2',
#   'Opposition': 'v Ireland',
#   'Ground': 'Nottingham',
#   'Start Date': '10 Jun 2009',
#   'Year': '2009'},
#  'T20I # 105': {'Runs': 5,
#   'Mins': '6',
#   'BF': '3',
#   '4s': '1',
#   '6s': '0',
#   'SR': '166.66',
#   'Pos': '2',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v West Indies',
#   'Ground': "Lord's",
#   'Start Date': '12 Jun 2009',
#   'Year': '2009'},
#  'T20I # 109': {'Runs': 9,
#   'Mins': '7',
#   'BF': '8',
#   '4s': '1',
#   '6s': '0',
#   'SR': '112.50',
#   'Pos': '2',
#   'Dismissal': 'bowled',
#   'Inns': '2',
#   'Opposition': 'v England',
#   'Ground': "Lord's",
#   'Start Date': '14 Jun 2009',
#   'Year': '2009'},
#  'T20I # 113': {'Runs': 29,
#   'Mins': '39',
#   'BF': '28',
#   '4s': '3',
#   '6s': '0',
#   'SR': '103.57',
#   'Pos': '2',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v South Africa',
#   'Ground': 'Nottingham',
#   'Start Date': '16 Jun 2009',
#   'Year': '2009'},
#  'T20I # 126': {'Runs': 3,
#   'Mins': '-',
#   'BF': '4',
#   '4s': '0',
#   '6s': '0',
#   'SR': '75.00',
#   'Pos': '5',
#   'Dismissal': 'run out',
#   'Inns': '2',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Nagpur',
#   'Start Date': '9 Dec 2009',
#   'Year': '2009'},
#  'T20I # 165': {'Runs': 79,
#   'Mins': '65',
#   'BF': '46',
#   '4s': '4',
#   '6s': '6',
#   'SR': '171.73',
#   'Pos': '4',
#   'Dismissal': 'not out',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Bridgetown',
#   'Start Date': '7 May 2010',
#   'Year': '2010'},
#  'T20I # 169': {'Runs': 5,
#   'Mins': '10',
#   'BF': '8',
#   '4s': '1',
#   '6s': '0',
#   'SR': '62.50',
#   'Pos': '4',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v West Indies',
#   'Ground': 'Bridgetown',
#   'Start Date': '9 May 2010',
#   'Year': '2010'},
#  'T20I # 173': {'Runs': 0,
#   'Mins': '-',
#   'BF': '-',
#   '4s': '-',
#   '6s': '-',
#   'SR': '-',
#   'Pos': '-',
#   'Dismissal': '-',
#   'Inns': '1',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Gros Islet',
#   'Start Date': '11 May 2010',
#   'Year': '2010'},
#  'T20I # 182': {'Runs': 10,
#   'Mins': '22',
#   'BF': '15',
#   '4s': '1',
#   '6s': '0',
#   'SR': '66.66',
#   'Pos': '4',
#   'Dismissal': 'stumped',
#   'Inns': '2',
#   'Opposition': 'v Zimbabwe',
#   'Ground': 'Harare',
#   'Start Date': '12 Jun 2010',
#   'Year': '2010'},
#  'T20I # 183': {'Runs': 0,
#   'Mins': '1',
#   'BF': '0',
#   '4s': '0',
#   '6s': '0',
#   'SR': '-',
#   'Pos': '5',
#   'Dismissal': 'not out',
#   'Inns': '2',
#   'Opposition': 'v Zimbabwe',
#   'Ground': 'Harare',
#   'Start Date': '13 Jun 2010',
#   'Year': '2010'},
#  'T20I # 196': {'Runs': 53,
#   'Mins': '38',
#   'BF': '34',
#   '4s': '5',
#   '6s': '2',
#   'SR': '155.88',
#   'Pos': '3',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v South Africa',
#   'Ground': 'Durban',
#   'Start Date': '9 Jan 2011',
#   'Year': '2011'},
#  'T20I # 200': {'Runs': 26,
#   'Mins': '33',
#   'BF': '23',
#   '4s': '0',
#   '6s': '2',
#   'SR': '113.04',
#   'Pos': '6',
#   'Dismissal': 'bowled',
#   'Inns': '1',
#   'Opposition': 'v West Indies',
#   'Ground': 'Port of Spain',
#   'Start Date': '4 Jun 2011',
#   'Year': '2011'},
#  'T20I # 204': {'Runs': 1,
#   'Mins': '7',
#   'BF': '3',
#   '4s': '0',
#   '6s': '0',
#   'SR': '33.33',
#   'Pos': '5',
#   'Dismissal': 'stumped',
#   'Inns': '1',
#   'Opposition': 'v England',
#   'Ground': 'Manchester',
#   'Start Date': '31 Aug 2011',
#   'Year': '2011'},
#  'T20I # 217': {'Runs': 0,
#   'Mins': '2',
#   'BF': '1',
#   '4s': '0',
#   '6s': '0',
#   'SR': '0.00',
#   'Pos': '5',
#   'Dismissal': 'bowled',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Sydney',
#   'Start Date': '1 Feb 2012',
#   'Year': '2012'},
#  'T20I # 218': {'Runs': 0,
#   'Mins': '-',
#   'BF': '-',
#   '4s': '-',
#   '6s': '-',
#   'SR': '-',
#   'Pos': '-',
#   'Dismissal': '-',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Melbourne',
#   'Start Date': '3 Feb 2012',
#   'Year': '2012'},
#  'T20I # 242': {'Runs': 0,
#   'Mins': '-',
#   'BF': '-',
#   '4s': '-',
#   '6s': '-',
#   'SR': '-',
#   'Pos': '-',
#   'Dismissal': '-',
#   'Inns': '2',
#   'Opposition': 'v South Africa',
#   'Ground': 'Johannesburg',
#   'Start Date': '30 Mar 2012',
#   'Year': '2012'},
#  'T20I # 255': {'Runs': 0,
#   'Mins': '-',
#   'BF': '-',
#   '4s': '-',
#   '6s': '-',
#   'SR': '-',
#   'Pos': '-',
#   'Dismissal': '-',
#   'Inns': '1',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Pallekele',
#   'Start Date': '7 Aug 2012',
#   'Year': '2012'},
#  'T20I # 261': {'Runs': 4,
#   'Mins': '2',
#   'BF': '2',
#   '4s': '0',
#   '6s': '0',
#   'SR': '200.00',
#   'Pos': '6',
#   'Dismissal': 'not out',
#   'Inns': '2',
#   'Opposition': 'v New Zealand',
#   'Ground': 'Chennai',
#   'Start Date': '11 Sep 2012',
#   'Year': '2012'},
#  'T20I # 265': {'Runs': 1,
#   'Mins': '2',
#   'BF': '1',
#   '4s': '0',
#   '6s': '0',
#   'SR': '100.00',
#   'Pos': '7',
#   'Dismissal': 'not out',
#   'Inns': '1',
#   'Opposition': 'v Afghanistan',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '19 Sep 2012',
#   'Year': '2012'},
#  'T20I # 272': {'Runs': 55,
#   'Mins': '48',
#   'BF': '33',
#   '4s': '5',
#   '6s': '1',
#   'SR': '166.66',
#   'Pos': '4',
#   'Dismissal': 'not out',
#   'Inns': '1',
#   'Opposition': 'v England',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '23 Sep 2012',
#   'Year': '2012'},
#  'T20I # 278': {'Runs': 1,
#   'Mins': '5',
#   'BF': '2',
#   '4s': '0',
#   '6s': '0',
#   'SR': '50.00',
#   'Pos': '5',
#   'Dismissal': 'bowled',
#   'Inns': '1',
#   'Opposition': 'v Australia',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '28 Sep 2012',
#   'Year': '2012'},
#  'T20I # 282': {'Runs': 0,
#   'Mins': '-',
#   'BF': '-',
#   '4s': '-',
#   '6s': '-',
#   'SR': '-',
#   'Pos': '-',
#   'Dismissal': '-',
#   'Inns': '2',
#   'Opposition': 'v Pakistan',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '30 Sep 2012',
#   'Year': '2012'},
#  'T20I # 286': {'Runs': 25,
#   'Mins': '48',
#   'BF': '27',
#   '4s': '2',
#   '6s': '0',
#   'SR': '92.59',
#   'Pos': '4',
#   'Dismissal': 'lbw',
#   'Inns': '1',
#   'Opposition': 'v South Africa',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '2 Oct 2012',
#   'Year': '2012'},
#  'T20I # 294': {'Runs': 24,
#   'Mins': '28',
#   'BF': '19',
#   '4s': '1',
#   '6s': '1',
#   'SR': '126.31',
#   'Pos': '5',
#   'Dismissal': 'bowled',
#   'Inns': '1',
#   'Opposition': 'v England',
#   'Ground': 'Mumbai',
#   'Start Date': '22 Dec 2012',
#   'Year': '2012'},
#  'T20I # 296': {'Runs': 2,
#   'Mins': '8',
#   'BF': '2',
#   '4s': '0',
#   '6s': '0',
#   'SR': '100.00',
#   'Pos': '7',
#   'Dismissal': 'run out',
#   'Inns': '1',
#   'Opposition': 'v Pakistan',
#   'Ground': 'Bengaluru',
#   'Start Date': '25 Dec 2012',
#   'Year': '2012'},
#  'T20I # 298': {'Runs': 4,
#   'Mins': '1',
#   'BF': '2',
#   '4s': '1',
#   '6s': '0',
#   'SR': '200.00',
#   'Pos': '7',
#   'Dismissal': 'not out',
#   'Inns': '1',
#   'Opposition': 'v Pakistan',
#   'Ground': 'Ahmedabad',
#   'Start Date': '28 Dec 2012',
#   'Year': '2012'},
#  'T20I # 331': {'Runs': 8,
#   'Mins': '8',
#   'BF': '8',
#   '4s': '0',
#   '6s': '1',
#   'SR': '100.00',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Rajkot',
#   'Start Date': '10 Oct 2013',
#   'Year': '2013'},
#  'T20I # 378': {'Runs': 24,
#   'Mins': '41',
#   'BF': '21',
#   '4s': '1',
#   '6s': '2',
#   'SR': '114.28',
#   'Pos': '1',
#   'Dismissal': 'bowled',
#   'Inns': '2',
#   'Opposition': 'v Pakistan',
#   'Ground': 'Dhaka',
#   'Start Date': '21 Mar 2014',
#   'Year': '2014'},
#  'T20I # 382': {'Runs': 62,
#   'Mins': '83',
#   'BF': '55',
#   '4s': '5',
#   '6s': '2',
#   'SR': '112.72',
#   'Pos': '1',
#   'Dismissal': 'not out',
#   'Inns': '2',
#   'Opposition': 'v West Indies',
#   'Ground': 'Dhaka',
#   'Start Date': '23 Mar 2014',
#   'Year': '2014'},
#  'T20I # 389': {'Runs': 56,
#   'Mins': '60',
#   'BF': '44',
#   '4s': '5',
#   '6s': '1',
#   'SR': '127.27',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Bangladesh',
#   'Ground': 'Dhaka',
#   'Start Date': '28 Mar 2014',
#   'Year': '2014'},
#  'T20I # 393': {'Runs': 5,
#   'Mins': '1',
#   'BF': '3',
#   '4s': '1',
#   '6s': '0',
#   'SR': '166.66',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Australia',
#   'Ground': 'Dhaka',
#   'Start Date': '30 Mar 2014',
#   'Year': '2014'},
#  'T20I # 399': {'Runs': 24,
#   'Mins': '17',
#   'BF': '13',
#   '4s': '4',
#   '6s': '1',
#   'SR': '184.61',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v South Africa',
#   'Ground': 'Dhaka',
#   'Start Date': '4 Apr 2014',
#   'Year': '2014'},
#  'T20I # 400': {'Runs': 29,
#   'Mins': '41',
#   'BF': '26',
#   '4s': '3',
#   '6s': '0',
#   'SR': '111.53',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Dhaka',
#   'Start Date': '6 Apr 2014',
#   'Year': '2014'},
#  'T20I # 456': {'Runs': 106,
#   'Mins': '79',
#   'BF': '66',
#   '4s': '12',
#   '6s': '5',
#   'SR': '160.60',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v South Africa',
#   'Ground': 'Dharamsala',
#   'Start Date': '2 Oct 2015',
#   'Year': '2015'},
#  'T20I # 457': {'Runs': 22,
#   'Mins': '40',
#   'BF': '24',
#   '4s': '2',
#   '6s': '0',
#   'SR': '91.66',
#   'Pos': '1',
#   'Dismissal': 'run out',
#   'Inns': '1',
#   'Opposition': 'v South Africa',
#   'Ground': 'Cuttack',
#   'Start Date': '5 Oct 2015',
#   'Year': '2015'},
#  'T20I # 485': {'Runs': 31,
#   'Mins': '21',
#   'BF': '20',
#   '4s': '4',
#   '6s': '1',
#   'SR': '155.00',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Australia',
#   'Ground': 'Adelaide',
#   'Start Date': '26 Jan 2016',
#   'Year': '2016'},
#  'T20I # 486': {'Runs': 60,
#   'Mins': '69',
#   'BF': '47',
#   '4s': '5',
#   '6s': '2',
#   'SR': '127.65',
#   'Pos': '1',
#   'Dismissal': 'run out',
#   'Inns': '1',
#   'Opposition': 'v Australia',
#   'Ground': 'Melbourne',
#   'Start Date': '29 Jan 2016',
#   'Year': '2016'},
#  'T20I # 489': {'Runs': 52,
#   'Mins': '57',
#   'BF': '38',
#   '4s': '5',
#   '6s': '1',
#   'SR': '136.84',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Sydney',
#   'Start Date': '31 Jan 2016',
#   'Year': '2016'},
#  'T20I # 496': {'Runs': 0,
#   'Mins': '2',
#   'BF': '2',
#   '4s': '0',
#   '6s': '0',
#   'SR': '0.00',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Pune',
#   'Start Date': '9 Feb 2016',
#   'Year': '2016'},
#  'T20I # 497': {'Runs': 43,
#   'Mins': '-',
#   'BF': '36',
#   '4s': '2',
#   '6s': '1',
#   'SR': '119.44',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Ranchi',
#   'Start Date': '12 Feb 2016',
#   'Year': '2016'},
#  'T20I # 499': {'Runs': 13,
#   'Mins': '-',
#   'BF': '13',
#   '4s': '1',
#   '6s': '1',
#   'SR': '100.00',
#   'Pos': '1',
#   'Dismissal': 'lbw',
#   'Inns': '2',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Visakhapatnam',
#   'Start Date': '14 Feb 2016',
#   'Year': '2016'},
#  'T20I # 509': {'Runs': 83,
#   'Mins': '90',
#   'BF': '55',
#   '4s': '7',
#   '6s': '3',
#   'SR': '150.90',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Bangladesh',
#   'Ground': 'Dhaka',
#   'Start Date': '24 Feb 2016',
#   'Year': '2016'},
#  'T20I # 512': {'Runs': 0,
#   'Mins': '2',
#   'BF': '2',
#   '4s': '0',
#   '6s': '0',
#   'SR': '0.00',
#   'Pos': '1',
#   'Dismissal': 'lbw',
#   'Inns': '2',
#   'Opposition': 'v Pakistan',
#   'Ground': 'Dhaka',
#   'Start Date': '27 Feb 2016',
#   'Year': '2016'},
#  'T20I # 515': {'Runs': 15,
#   'Mins': '15',
#   'BF': '14',
#   '4s': '3',
#   '6s': '0',
#   'SR': '107.14',
#   'Pos': '2',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Dhaka',
#   'Start Date': '1 Mar 2016',
#   'Year': '2016'},
#  'T20I # 517': {'Runs': 39,
#   'Mins': '26',
#   'BF': '28',
#   '4s': '7',
#   '6s': '1',
#   'SR': '139.28',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v U.A.E.',
#   'Ground': 'Dhaka',
#   'Start Date': '3 Mar 2016',
#   'Year': '2016'},
#  'T20I # 521': {'Runs': 1,
#   'Mins': '8',
#   'BF': '5',
#   '4s': '0',
#   '6s': '0',
#   'SR': '20.00',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Bangladesh',
#   'Ground': 'Dhaka',
#   'Start Date': '6 Mar 2016',
#   'Year': '2016'},
#  'T20I # 535': {'Runs': 5,
#   'Mins': '-',
#   'BF': '7',
#   '4s': '0',
#   '6s': '0',
#   'SR': '71.42',
#   'Pos': '1',
#   'Dismissal': 'stumped',
#   'Inns': '2',
#   'Opposition': 'v New Zealand',
#   'Ground': 'Nagpur',
#   'Start Date': '15 Mar 2016',
#   'Year': '2016'},
#  'T20I # 541': {'Runs': 10,
#   'Mins': '11',
#   'BF': '11',
#   '4s': '2',
#   '6s': '0',
#   'SR': '90.90',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Pakistan',
#   'Ground': 'Kolkata',
#   'Start Date': '19 Mar 2016',
#   'Year': '2016'},
#  'T20I # 547': {'Runs': 18,
#   'Mins': '29',
#   'BF': '16',
#   '4s': '1',
#   '6s': '1',
#   'SR': '112.50',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Bangladesh',
#   'Ground': 'Bengaluru',
#   'Start Date': '23 Mar 2016',
#   'Year': '2016'},
#  'T20I # 553': {'Runs': 12,
#   'Mins': '25',
#   'BF': '17',
#   '4s': '1',
#   '6s': '0',
#   'SR': '70.58',
#   'Pos': '1',
#   'Dismissal': 'bowled',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Mohali',
#   'Start Date': '27 Mar 2016',
#   'Year': '2016'},
#  'T20I # 556': {'Runs': 43,
#   'Mins': '29',
#   'BF': '31',
#   '4s': '3',
#   '6s': '3',
#   'SR': '138.70',
#   'Pos': '1',
#   'Dismissal': 'lbw',
#   'Inns': '1',
#   'Opposition': 'v West Indies',
#   'Ground': 'Mumbai',
#   'Start Date': '31 Mar 2016',
#   'Year': '2016'},
#  'T20I # 562': {'Runs': 62,
#   'Mins': '54',
#   'BF': '28',
#   '4s': '4',
#   '6s': '4',
#   'SR': '221.42',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v West Indies',
#   'Ground': 'Lauderhill',
#   'Start Date': '27 Aug 2016',
#   'Year': '2016'},
#  'T20I # 563': {'Runs': 10,
#   'Mins': '9',
#   'BF': '8',
#   '4s': '0',
#   '6s': '1',
#   'SR': '125.00',
#   'Pos': '1',
#   'Dismissal': 'not out',
#   'Inns': '2',
#   'Opposition': 'v West Indies',
#   'Ground': 'Lauderhill',
#   'Start Date': '28 Aug 2016',
#   'Year': '2016'},
#  'T20I # 618': {'Runs': 9,
#   'Mins': '-',
#   'BF': '8',
#   '4s': '1',
#   '6s': '0',
#   'SR': '112.50',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '6 Sep 2017',
#   'Year': '2017'},
#  'T20I # 623': {'Runs': 11,
#   'Mins': '5',
#   'BF': '7',
#   '4s': '1',
#   '6s': '1',
#   'SR': '157.14',
#   'Pos': '1',
#   'Dismissal': 'bowled',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Ranchi',
#   'Start Date': '7 Oct 2017',
#   'Year': '2017'},
#  'T20I # 624': {'Runs': 8,
#   'Mins': '3',
#   'BF': '4',
#   '4s': '2',
#   '6s': '0',
#   'SR': '200.00',
#   'Pos': '1',
#   'Dismissal': 'lbw',
#   'Inns': '1',
#   'Opposition': 'v Australia',
#   'Ground': 'Guwahati',
#   'Start Date': '10 Oct 2017',
#   'Year': '2017'},
#  'T20I # 630': {'Runs': 80,
#   'Mins': '85',
#   'BF': '55',
#   '4s': '6',
#   '6s': '4',
#   'SR': '145.45',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v New Zealand',
#   'Ground': 'Delhi',
#   'Start Date': '1 Nov 2017',
#   'Year': '2017'},
#  'T20I # 631': {'Runs': 5,
#   'Mins': '9',
#   'BF': '6',
#   '4s': '1',
#   '6s': '0',
#   'SR': '83.33',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v New Zealand',
#   'Ground': 'Rajkot',
#   'Start Date': '4 Nov 2017',
#   'Year': '2017'},
#  'T20I # 632': {'Runs': 8,
#   'Mins': '11',
#   'BF': '9',
#   '4s': '1',
#   '6s': '0',
#   'SR': '88.88',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v New Zealand',
#   'Ground': 'Thiruvananthapuram',
#   'Start Date': '7 Nov 2017',
#   'Year': '2017'},
#  'T20I # 633': {'Runs': 17,
#   'Mins': '21',
#   'BF': '13',
#   '4s': '2',
#   '6s': '0',
#   'SR': '130.76',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Cuttack',
#   'Start Date': '20 Dec 2017',
#   'Year': '2017'},
#  'T20I # 634': {'Runs': 118,
#   'Mins': '61',
#   'BF': '43',
#   '4s': '12',
#   '6s': '10',
#   'SR': '274.41',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Indore',
#   'Start Date': '22 Dec 2017',
#   'Year': '2017'},
#  'T20I # 635': {'Runs': 27,
#   'Mins': '31',
#   'BF': '20',
#   '4s': '4',
#   '6s': '1',
#   'SR': '135.00',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Mumbai',
#   'Start Date': '24 Dec 2017',
#   'Year': '2017'},
#  'T20I # 652': {'Runs': 21,
#   'Mins': '8',
#   'BF': '9',
#   '4s': '2',
#   '6s': '2',
#   'SR': '233.33',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v South Africa',
#   'Ground': 'Johannesburg',
#   'Start Date': '18 Feb 2018',
#   'Year': '2018'},
#  'T20I # 654': {'Runs': 0,
#   'Mins': '5',
#   'BF': '1',
#   '4s': '0',
#   '6s': '0',
#   'SR': '0.00',
#   'Pos': '2',
#   'Dismissal': 'lbw',
#   'Inns': '1',
#   'Opposition': 'v South Africa',
#   'Ground': 'Centurion',
#   'Start Date': '21 Feb 2018',
#   'Year': '2018'},
#  'T20I # 655': {'Runs': 11,
#   'Mins': '9',
#   'BF': '8',
#   '4s': '2',
#   '6s': '0',
#   'SR': '137.50',
#   'Pos': '1',
#   'Dismissal': 'lbw',
#   'Inns': '1',
#   'Opposition': 'v South Africa',
#   'Ground': 'Cape Town',
#   'Start Date': '24 Feb 2018',
#   'Year': '2018'},
#  'T20I # 656': {'Runs': 0,
#   'Mins': '-',
#   'BF': '4',
#   '4s': '0',
#   '6s': '0',
#   'SR': '0.00',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '6 Mar 2018',
#   'Year': '2018'},
#  'T20I # 657': {'Runs': 17,
#   'Mins': '-',
#   'BF': '13',
#   '4s': '3',
#   '6s': '0',
#   'SR': '130.76',
#   'Pos': '1',
#   'Dismissal': 'bowled',
#   'Inns': '2',
#   'Opposition': 'v Bangladesh',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '8 Mar 2018',
#   'Year': '2018'},
#  'T20I # 659': {'Runs': 11,
#   'Mins': '-',
#   'BF': '7',
#   '4s': '1',
#   '6s': '1',
#   'SR': '157.14',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Sri Lanka',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '12 Mar 2018',
#   'Year': '2018'},
#  'T20I # 660': {'Runs': 89,
#   'Mins': '-',
#   'BF': '61',
#   '4s': '5',
#   '6s': '5',
#   'SR': '145.90',
#   'Pos': '1',
#   'Dismissal': 'run out',
#   'Inns': '1',
#   'Opposition': 'v Bangladesh',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '14 Mar 2018',
#   'Year': '2018'},
#  'T20I # 662': {'Runs': 56,
#   'Mins': '-',
#   'BF': '42',
#   '4s': '4',
#   '6s': '3',
#   'SR': '133.33',
#   'Pos': '2',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Bangladesh',
#   'Ground': 'Colombo (RPS)',
#   'Start Date': '18 Mar 2018',
#   'Year': '2018'},
#  'T20I # 678': {'Runs': 97,
#   'Mins': '87',
#   'BF': '61',
#   '4s': '8',
#   '6s': '5',
#   'SR': '159.01',
#   'Pos': '1',
#   'Dismissal': 'bowled',
#   'Inns': '1',
#   'Opposition': 'v Ireland',
#   'Ground': 'Dublin (Malahide)',
#   'Start Date': '27 Jun 2018',
#   'Year': '2018'},
#  'T20I # 680': {'Runs': 0,
#   'Mins': '-',
#   'BF': '2',
#   '4s': '0',
#   '6s': '0',
#   'SR': '0.00',
#   'Pos': '4',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Ireland',
#   'Ground': 'Dublin (Malahide)',
#   'Start Date': '29 Jun 2018',
#   'Year': '2018'},
#  'T20I # 684': {'Runs': 32,
#   'Mins': '-',
#   'BF': '30',
#   '4s': '3',
#   '6s': '1',
#   'SR': '106.66',
#   'Pos': '2',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v England',
#   'Ground': 'Manchester',
#   'Start Date': '3 Jul 2018',
#   'Year': '2018'},
#  'T20I # 688': {'Runs': 5,
#   'Mins': '-',
#   'BF': '9',
#   '4s': '1',
#   '6s': '0',
#   'SR': '55.55',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v England',
#   'Ground': 'Cardiff',
#   'Start Date': '6 Jul 2018',
#   'Year': '2018'},
#  'T20I # 690': {'Runs': 100,
#   'Mins': '-',
#   'BF': '56',
#   '4s': '11',
#   '6s': '5',
#   'SR': '178.57',
#   'Pos': '1',
#   'Dismissal': 'not out',
#   'Inns': '2',
#   'Opposition': 'v England',
#   'Ground': 'Bristol',
#   'Start Date': '8 Jul 2018',
#   'Year': '2018'},
#  'T20I # 707': {'Runs': 6,
#   'Mins': '-',
#   'BF': '6',
#   '4s': '1',
#   '6s': '0',
#   'SR': '100.00',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v West Indies',
#   'Ground': 'Kolkata',
#   'Start Date': '4 Nov 2018',
#   'Year': '2018'},
#  'T20I # 709': {'Runs': 111,
#   'Mins': '95',
#   'BF': '61',
#   '4s': '8',
#   '6s': '7',
#   'SR': '181.96',
#   'Pos': '1',
#   'Dismissal': 'not out',
#   'Inns': '1',
#   'Opposition': 'v West Indies',
#   'Ground': 'Lucknow',
#   'Start Date': '6 Nov 2018',
#   'Year': '2018'},
#  'T20I # 710': {'Runs': 4,
#   'Mins': '-',
#   'BF': '6',
#   '4s': '1',
#   '6s': '0',
#   'SR': '66.66',
#   'Pos': '2',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v West Indies',
#   'Ground': 'Chennai',
#   'Start Date': '11 Nov 2018',
#   'Year': '2018'},
#  'T20I # 712': {'Runs': 7,
#   'Mins': '-',
#   'BF': '8',
#   '4s': '0',
#   '6s': '0',
#   'SR': '87.50',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Brisbane',
#   'Start Date': '21 Nov 2018',
#   'Year': '2018'},
#  'T20I # 713': {'Runs': 0,
#   'Mins': '-',
#   'BF': '-',
#   '4s': '-',
#   '6s': '-',
#   'SR': '-',
#   'Pos': '-',
#   'Dismissal': '-',
#   'Inns': '-',
#   'Opposition': 'v Australia',
#   'Ground': 'Melbourne',
#   'Start Date': '23 Nov 2018',
#   'Year': '2018'},
#  'T20I # 714': {'Runs': 23,
#   'Mins': '-',
#   'BF': '16',
#   '4s': '1',
#   '6s': '2',
#   'SR': '143.75',
#   'Pos': '1',
#   'Dismissal': 'bowled',
#   'Inns': '2',
#   'Opposition': 'v Australia',
#   'Ground': 'Sydney',
#   'Start Date': '25 Nov 2018',
#   'Year': '2018'},
#  'T20I # 735': {'Runs': 1,
#   'Mins': '10',
#   'BF': '5',
#   '4s': '0',
#   '6s': '0',
#   'SR': '20.00',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v New Zealand',
#   'Ground': 'Wellington',
#   'Start Date': '6 Feb 2019',
#   'Year': '2019'},
#  'T20I # 737': {'Runs': 50,
#   'Mins': '40',
#   'BF': '29',
#   '4s': '3',
#   '6s': '4',
#   'SR': '172.41',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v New Zealand',
#   'Ground': 'Auckland',
#   'Start Date': '8 Feb 2019',
#   'Year': '2019'},
#  'T20I # 738': {'Runs': 38,
#   'Mins': '63',
#   'BF': '32',
#   '4s': '3',
#   '6s': '0',
#   'SR': '118.75',
#   'Pos': '2',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v New Zealand',
#   'Ground': 'Hamilton',
#   'Start Date': '10 Feb 2019',
#   'Year': '2019'},
#  'T20I # 748': {'Runs': 5,
#   'Mins': '11',
#   'BF': '8',
#   '4s': '0',
#   '6s': '0',
#   'SR': '62.50',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v Australia',
#   'Ground': 'Visakhapatnam',
#   'Start Date': '24 Feb 2019',
#   'Year': '2019'},
#  'T20I # 842': {'Runs': 24,
#   'Mins': '-',
#   'BF': '25',
#   '4s': '2',
#   '6s': '2',
#   'SR': '96.00',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '2',
#   'Opposition': 'v West Indies',
#   'Ground': 'Lauderhill',
#   'Start Date': '3 Aug 2019',
#   'Year': '2019'},
#  'T20I # 843': {'Runs': 67,
#   'Mins': '-',
#   'BF': '51',
#   '4s': '6',
#   '6s': '3',
#   'SR': '131.37',
#   'Pos': '1',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v West Indies',
#   'Ground': 'Lauderhill',
#   'Start Date': '4 Aug 2019',
#   'Year': '2019'},
#  'T20I # 888': {'Runs': 12,
#   'Mins': '21',
#   'BF': '12',
#   '4s': '0',
#   '6s': '2',
#   'SR': '100.00',
#   'Pos': '1',
#   'Dismissal': 'lbw',
#   'Inns': '2',
#   'Opposition': 'v South Africa',
#   'Ground': 'Mohali',
#   'Start Date': '18 Sep 2019',
#   'Year': '2019'},
#  'T20I # 893': {'Runs': 9,
#   'Mins': '11',
#   'BF': '8',
#   '4s': '2',
#   '6s': '0',
#   'SR': '112.50',
#   'Pos': '2',
#   'Dismissal': 'caught',
#   'Inns': '1',
#   'Opposition': 'v South Africa',
#   'Ground': 'Bengaluru',
#   'Start Date': '22 Sep 2019',
#   'Year': '2019'}}

# %%
res = data_frame.groupby(['Year']).agg({'Runs': 'sum','Opposition':'count'})
res=res.rename(columns = {'Opposition':'Matches'})
dictio = res.to_dict('index')
res.reset_index(level=0, inplace=True)
res
# Out:
#     Year  Runs  Matches
# 0   2007    88        5
# 1   2008     8        1
# 2   2009   145        8
# 3   2010    94        5
# 4   2011    80        3
# 5   2012   116       13
# 6   2013     8        1
# 7   2014   200        6
# 8   2015   128        2
# 9   2016   497       18
# 10  2017   283        9
# 11  2018   590       19
# 12  2019   206        8

# %%
# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')
# from matplotlib.figure import Figure


plt.figure(figsize=(20,20))
plt.figure().suptitle('test title', fontsize=20)
res.plot(kind='bar',x="Year",y='Runs',color='Blue',title=player_name)
plt.savefig("file.jpg",dpi=200)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
data_frame
# Out:
#             Runs Mins  BF  4s  6s      SR Pos Dismissal Inns      Opposition  \
# Match No
# T20I # 40      0    -   -   -   -       -   -         -    1       v England
# T20I # 43     50   52  40   7   2  125.00   5   not out    1  v South Africa
# T20I # 45      8   11   5   0   1  160.00   6   not out    1     v Australia
# T20I # 46     30   22  16   2   1  187.50   6   not out    1      v Pakistan
# T20I # 47      0    -   -   -   -       -   -         -    2     v Australia
# T20I # 52      8   15   8   1   0  100.00   5    bowled    1     v Australia
# T20I # 82      4   13  11   0   0   36.36   6    caught    2     v Sri Lanka
# T20I # 84      7    9   7   0   1  100.00   4    caught    1   v New Zealand
# T20I # 93     36   34  23   3   2  156.52   2    bowled    1    v Bangladesh
# T20I # 101    52   61  45   4   1  115.55   2   not out    2       v Ireland
# T20I # 105     5    6   3   1   0  166.66   2    caught    1   v West Indies
# T20I # 109     9    7   8   1   0  112.50   2    bowled    2       v England
# T20I # 113    29   39  28   3   0  103.57   2    caught    2  v South Africa
# T20I # 126     3    -   4   0   0   75.00   5   run out    2     v Sri Lanka
# T20I # 165    79   65  46   4   6  171.73   4   not out    2     v Australia
# T20I # 169     5   10   8   1   0   62.50   4    caught    2   v West Indies
# T20I # 173     0    -   -   -   -       -   -         -    1     v Sri Lanka
# T20I # 182    10   22  15   1   0   66.66   4   stumped    2      v Zimbabwe
# T20I # 183     0    1   0   0   0       -   5   not out    2      v Zimbabwe
# T20I # 196    53   38  34   5   2  155.88   3    caught    1  v South Africa
# T20I # 200    26   33  23   0   2  113.04   6    bowled    1   v West Indies
# T20I # 204     1    7   3   0   0   33.33   5   stumped    1       v England
# T20I # 217     0    2   1   0   0    0.00   5    bowled    2     v Australia
# T20I # 218     0    -   -   -   -       -   -         -    2     v Australia
# T20I # 242     0    -   -   -   -       -   -         -    2  v South Africa
# T20I # 255     0    -   -   -   -       -   -         -    1     v Sri Lanka
# T20I # 261     4    2   2   0   0  200.00   6   not out    2   v New Zealand
# T20I # 265     1    2   1   0   0  100.00   7   not out    1   v Afghanistan
# T20I # 272    55   48  33   5   1  166.66   4   not out    1       v England
# T20I # 278     1    5   2   0   0   50.00   5    bowled    1     v Australia
# ...          ...  ...  ..  ..  ..     ...  ..       ...  ...             ...
# T20I # 633    17   21  13   2   0  130.76   1    caught    1     v Sri Lanka
# T20I # 634   118   61  43  12  10  274.41   1    caught    1     v Sri Lanka
# T20I # 635    27   31  20   4   1  135.00   1    caught    2     v Sri Lanka
# T20I # 652    21    8   9   2   2  233.33   1    caught    1  v South Africa
# T20I # 654     0    5   1   0   0    0.00   2       lbw    1  v South Africa
# T20I # 655    11    9   8   2   0  137.50   1       lbw    1  v South Africa
# T20I # 656     0    -   4   0   0    0.00   1    caught    1     v Sri Lanka
# T20I # 657    17    -  13   3   0  130.76   1    bowled    2    v Bangladesh
# T20I # 659    11    -   7   1   1  157.14   1    caught    2     v Sri Lanka
# T20I # 660    89    -  61   5   5  145.90   1   run out    1    v Bangladesh
# T20I # 662    56    -  42   4   3  133.33   2    caught    2    v Bangladesh
# T20I # 678    97   87  61   8   5  159.01   1    bowled    1       v Ireland
# T20I # 680     0    -   2   0   0    0.00   4    caught    1       v Ireland
# T20I # 684    32    -  30   3   1  106.66   2    caught    2       v England
# T20I # 688     5    -   9   1   0   55.55   1    caught    1       v England
# T20I # 690   100    -  56  11   5  178.57   1   not out    2       v England
# T20I # 707     6    -   6   1   0  100.00   1    caught    2   v West Indies
# T20I # 709   111   95  61   8   7  181.96   1   not out    1   v West Indies
# T20I # 710     4    -   6   1   0   66.66   2    caught    2   v West Indies
# T20I # 712     7    -   8   0   0   87.50   1    caught    2     v Australia
# T20I # 713     0    -   -   -   -       -   -         -    -     v Australia
# T20I # 714    23    -  16   1   2  143.75   1    bowled    2     v Australia
# T20I # 735     1   10   5   0   0   20.00   1    caught    2   v New Zealand
# T20I # 737    50   40  29   3   4  172.41   1    caught    2   v New Zealand
# T20I # 738    38   63  32   3   0  118.75   2    caught    2   v New Zealand
# T20I # 748     5   11   8   0   0   62.50   1    caught    1     v Australia
# T20I # 842    24    -  25   2   2   96.00   1    caught    2   v West Indies
# T20I # 843    67    -  51   6   3  131.37   1    caught    1   v West Indies
# T20I # 888    12   21  12   0   2  100.00   1       lbw    2  v South Africa
# T20I # 893     9   11   8   2   0  112.50   2    caught    1  v South Africa
#
#                        Ground   Start Date  Year
# Match No
# T20I # 40              Durban  19 Sep 2007  2007
# T20I # 43              Durban  20 Sep 2007  2007
# T20I # 45              Durban  22 Sep 2007  2007
# T20I # 46        Johannesburg  24 Sep 2007  2007
# T20I # 47         Mumbai (BS)  20 Oct 2007  2007
# T20I # 52           Melbourne   1 Feb 2008  2008
# T20I # 82       Colombo (RPS)  10 Feb 2009  2009
# T20I # 84        Christchurch  25 Feb 2009  2009
# T20I # 93          Nottingham   6 Jun 2009  2009
# T20I # 101         Nottingham  10 Jun 2009  2009
# T20I # 105             Lord's  12 Jun 2009  2009
# T20I # 109             Lord's  14 Jun 2009  2009
# T20I # 113         Nottingham  16 Jun 2009  2009
# T20I # 126             Nagpur   9 Dec 2009  2009
# T20I # 165         Bridgetown   7 May 2010  2010
# T20I # 169         Bridgetown   9 May 2010  2010
# T20I # 173         Gros Islet  11 May 2010  2010
# T20I # 182             Harare  12 Jun 2010  2010
# T20I # 183             Harare  13 Jun 2010  2010
# T20I # 196             Durban   9 Jan 2011  2011
# T20I # 200      Port of Spain   4 Jun 2011  2011
# T20I # 204         Manchester  31 Aug 2011  2011
# T20I # 217             Sydney   1 Feb 2012  2012
# T20I # 218          Melbourne   3 Feb 2012  2012
# T20I # 242       Johannesburg  30 Mar 2012  2012
# T20I # 255          Pallekele   7 Aug 2012  2012
# T20I # 261            Chennai  11 Sep 2012  2012
# T20I # 265      Colombo (RPS)  19 Sep 2012  2012
# T20I # 272      Colombo (RPS)  23 Sep 2012  2012
# T20I # 278      Colombo (RPS)  28 Sep 2012  2012
# ...                       ...          ...   ...
# T20I # 633            Cuttack  20 Dec 2017  2017
# T20I # 634             Indore  22 Dec 2017  2017
# T20I # 635             Mumbai  24 Dec 2017  2017
# T20I # 652       Johannesburg  18 Feb 2018  2018
# T20I # 654          Centurion  21 Feb 2018  2018
# T20I # 655          Cape Town  24 Feb 2018  2018
# T20I # 656      Colombo (RPS)   6 Mar 2018  2018
# T20I # 657      Colombo (RPS)   8 Mar 2018  2018
# T20I # 659      Colombo (RPS)  12 Mar 2018  2018
# T20I # 660      Colombo (RPS)  14 Mar 2018  2018
# T20I # 662      Colombo (RPS)  18 Mar 2018  2018
# T20I # 678  Dublin (Malahide)  27 Jun 2018  2018
# T20I # 680  Dublin (Malahide)  29 Jun 2018  2018
# T20I # 684         Manchester   3 Jul 2018  2018
# T20I # 688            Cardiff   6 Jul 2018  2018
# T20I # 690            Bristol   8 Jul 2018  2018
# T20I # 707            Kolkata   4 Nov 2018  2018
# T20I # 709            Lucknow   6 Nov 2018  2018
# T20I # 710            Chennai  11 Nov 2018  2018
# T20I # 712           Brisbane  21 Nov 2018  2018
# T20I # 713          Melbourne  23 Nov 2018  2018
# T20I # 714             Sydney  25 Nov 2018  2018
# T20I # 735         Wellington   6 Feb 2019  2019
# T20I # 737           Auckland   8 Feb 2019  2019
# T20I # 738           Hamilton  10 Feb 2019  2019
# T20I # 748      Visakhapatnam  24 Feb 2019  2019
# T20I # 842         Lauderhill   3 Aug 2019  2019
# T20I # 843         Lauderhill   4 Aug 2019  2019
# T20I # 888             Mohali  18 Sep 2019  2019
# T20I # 893          Bengaluru  22 Sep 2019  2019
#
# [98 rows x 13 columns]
